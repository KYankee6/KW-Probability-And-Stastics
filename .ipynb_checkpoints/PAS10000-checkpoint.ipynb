# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

# %%
df = pd.read_excel('./result/UDtoLPD.xlsx')

# %%
 xtick= np.arange(0,1.1,0.001)
x = np.arange(0,1.0001,0.0001)
UD=df['UD']
LPD=df['LPD(0,1)']
LPD2=df['LPD(0,2)']
LPD3=df['LPD(2,5)']

# %%
plt.plot(x,UD)

# %%
plt.hist(UD,bins=100,density=True,histtype="step",cumulative=True)
# Out:
# (array([0.009999  , 0.01969803, 0.02959704, 0.0389961 , 0.04729527,
#         0.05719428, 0.06729327, 0.07779222, 0.08829117, 0.09679032,
#         0.10628937, 0.1159884 , 0.1259874 , 0.13618638, 0.14778522,
#         0.15728427, 0.16928307, 0.18038196, 0.19008099, 0.20107989,
#         0.21257874, 0.22237776, 0.23357664, 0.24357564, 0.25377462,
#         0.2629737 , 0.27277272, 0.28157184, 0.29117088, 0.2989701 ,
#         0.30786921, 0.31906809, 0.32916708, 0.33966603, 0.34816518,
#         0.35706429, 0.36966303, 0.37876212, 0.38876112, 0.39886011,
#         0.40865913, 0.41955804, 0.42915708, 0.43915608, 0.44825517,
#         0.45845415, 0.46825317, 0.4779522 , 0.48815118, 0.49935006,
#         0.50774923, 0.5190481 , 0.53014699, 0.53934607, 0.54984502,
#         0.560044  , 0.57084292, 0.58144186, 0.59184082, 0.60153985,
#         0.61143886, 0.62133787, 0.63273673, 0.64093591, 0.65183482,
#         0.66323368, 0.67273273, 0.68263174, 0.69183082, 0.70232977,
# ...

# %%
plt.bar(x,UD,width=0.0001,align='edge')
plt.xticks(xtick)
# Out:
# ([<matplotlib.axis.XTick at 0x2d4025a7648>,
# ...
#   ...],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
# ...

# %%
plt.hist(LPD2,bins=100,density=True,histtype="step",range=[-20,20])
# Out:
# (array([0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.        , 0.00025003, 0.        , 0.        ,
#         0.        , 0.00050005, 0.00025003, 0.        , 0.00025003,
#         0.00025003, 0.00050005, 0.00050005, 0.0010001 , 0.00025003,
#         0.00050005, 0.00125013, 0.0010001 , 0.00075008, 0.00075008,
#         0.00175018, 0.00275028, 0.00250025, 0.0030003 , 0.00425043,
#         0.00375038, 0.0060006 , 0.00825083, 0.00875088, 0.0090009 ,
#         0.01650165, 0.01625163, 0.01875188, 0.0210021 , 0.03275328,
#         0.03825383, 0.04225423, 0.0530053 , 0.07450745, 0.08775878,
#         0.10976098, 0.12026203, 0.14826483, 0.18176818, 0.2290229 ,
#         0.23177318, 0.18826883, 0.150015  , 0.12726273, 0.0970097 ,
#         0.07950795, 0.07125713, 0.05075508, 0.04650465, 0.03375338,
#         0.03125313, 0.0270027 , 0.01950195, 0.01750175, 0.01475148,
#         0.0110011 , 0.00925093, 0.00825083, 0.00575058, 0.0070007 ,
# ...

# %%
plt.hist(LPD3,bins=100,density=True,cumulative=True,range=[-20,20],histtype="step")
# Out:
# (array([6.12870276e-04, 9.19305414e-04, 1.53217569e-03, 2.04290092e-03,
#         2.96220633e-03, 3.88151175e-03, 4.18794688e-03, 5.20939734e-03,
#         6.12870276e-03, 6.94586313e-03, 8.27374872e-03, 9.70377937e-03,
#         1.12359551e-02, 1.22574055e-02, 1.38917263e-02, 1.47088866e-02,
#         1.65474974e-02, 1.84882533e-02, 2.20633299e-02, 2.43105209e-02,
#         2.67620020e-02, 2.92134831e-02, 3.21756895e-02, 3.49336057e-02,
#         3.86108274e-02, 4.14708887e-02, 4.50459653e-02, 4.88253320e-02,
#         5.47497446e-02, 6.05720123e-02, 6.58835546e-02, 7.21144025e-02,
#         7.96731359e-02, 8.64147089e-02, 9.34627171e-02, 1.01327886e-01,
#         1.11031665e-01, 1.20633299e-01, 1.31869254e-01, 1.45556691e-01,
#         1.59141982e-01, 1.75280899e-01, 1.89479060e-01, 2.07048008e-01,
#         2.26251277e-01, 2.46169561e-01, 2.65270684e-01, 2.86925434e-01,
#         3.07660878e-01, 3.35955056e-01, 3.62512768e-01, 3.93564862e-01,
# ...

# %%
x=plt.hist(LPD3,bins=100,cumulative=True, range=[-20,20],histtype='step')

# %%
y=plt.hist(LPD,bins=50,range=(-11,11),histtype="step",density=True)
y=plt.hist(LPD2,bins=50,color="red",range=(-11,11),histtype="step",density=True)
y=plt.hist(LPD3,bins=50,color="black",range=(-11,11),histtype="step",density=True)

# %%
O
# Out:
# array([-0.65299664,  0.69514723,  0.77560975, ...,  0.60558674,
#        -0.99834817,  1.19983603])

# %%
len(LPD)
# Out:
# 10001

# %%
x=plt.hist(O,bins=50,cumulative=True, range=(-11,11), density=True)
y=plt.hist(LPD2,bins=50,cumulative=True,color="red",range=(-11,11),histtype="step",density=True)

# %%
d=max(x[0]-y[0])

# %%
d
# Out:
# 0.013198680131986884
