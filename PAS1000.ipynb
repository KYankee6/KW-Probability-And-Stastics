# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('./result/UDtoLPD1000.xlsx')

# %%
 xtick= np.arange(0,1.1,0.001)
x = np.arange(0,1.001,0.001)
w=np.arange(0,1.001,0.001)
UD=df['UD']
LPD=df['LPD(0,1)']

# %%
plt.plot(x,UD)

# %%
plt.hist(UD,bins=10,histtype='bar')
# Out:
# (array([ 93., 118., 100.,  94., 102., 108., 105.,  94.,  93.,  94.]),
#  array([2.750000e-04, 1.001567e-01, 2.000384e-01, 2.999201e-01,
#         3.998018e-01, 4.996835e-01, 5.995652e-01, 6.994469e-01,
#         7.993286e-01, 8.992103e-01, 9.990920e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(UD,bins=1000,cumulative=True)
# Out:
# (array([   2.,    4.,    5.,    8.,    9.,    9.,   10.,   11.,   11.,
#           11.,   12.,   13.,   13.,   13.,   14.,   15.,   15.,   17.,
#           19.,   19.,   19.,   20.,   21.,   21.,   21.,   22.,   23.,
#           23.,   23.,   25.,   25.,   30.,   33.,   33.,   37.,   37.,
#           38.,   39.,   40.,   41.,   41.,   42.,   42.,   43.,   43.,
#           43.,   43.,   44.,   45.,   46.,   47.,   47.,   47.,   49.,
#           49.,   51.,   51.,   51.,   52.,   55.,   58.,   58.,   59.,
#           59.,   60.,   62.,   63.,   63.,   63.,   63.,   63.,   63.,
#           68.,   72.,   72.,   72.,   73.,   75.,   78.,   79.,   81.,
#           82.,   84.,   84.,   84.,   84.,   85.,   85.,   86.,   87.,
#           89.,   90.,   90.,   91.,   91.,   91.,   92.,   92.,   92.,
#           93.,   94.,   95.,   97.,   98.,   99.,  101.,  101.,  103.,
#          104.,  106.,  106.,  106.,  106.,  106.,  107.,  108.,  109.,
# ...

# %%
plt.plot(x,LPD)

# %%
plt.hist(LPD,bins=70)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  1.,  0.,  0.,  0.,  2.,  0.,  0.,  1.,
#          3.,  1.,  1.,  1.,  0.,  2.,  0.,  2.,  4.,  2.,  6., 12.,  4.,
#          8., 12., 21., 13., 21., 35., 41., 46., 48., 55., 71., 91., 94.,
#         75., 69., 50., 28., 43., 23., 15., 19., 13., 14., 11., 10.,  6.,
#          6.,  7.,  1.,  4.,  3.,  1.,  0.,  0.,  0.,  2.,  0.,  0.,  0.,
#          0.,  1.,  0.,  0.,  1.]),
#  array([-7.50432000e+00, -7.30695443e+00, -7.10958886e+00, -6.91222329e+00,
#         -6.71485771e+00, -6.51749214e+00, -6.32012657e+00, -6.12276100e+00,
#         -5.92539543e+00, -5.72802986e+00, -5.53066429e+00, -5.33329871e+00,
#         -5.13593314e+00, -4.93856757e+00, -4.74120200e+00, -4.54383643e+00,
#         -4.34647086e+00, -4.14910529e+00, -3.95173971e+00, -3.75437414e+00,
#         -3.55700857e+00, -3.35964300e+00, -3.16227743e+00, -2.96491186e+00,
#         -2.76754629e+00, -2.57018071e+00, -2.37281514e+00, -2.17544957e+00,
# ...

# %%
plt.hist(LPD,bins=1000,cumulative=True)
# Out:
# (array([1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
#         1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00, 1.000e+00,
# ...
